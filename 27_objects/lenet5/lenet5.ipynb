# %% [markdown]
# # 3D Object Recognition
# ---
# Zhiang Chen, Wyatt Newman
#
# Aug 2016

# %% [markdown]
# #### 1. import packages

# %%
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
import matplotlib.pyplot as plt
import random
import operator
import time
import os

# %% [markdown]
# #### 2. load data

# %%
file_name = 'depth_data'
with open(file_name, 'rb') as f:
    save = pickle.load(f)
    dataset = save['dataset']
    names = save['names']
    orientations = save['orientations']
    del save

# %% [markdown]
# #### 3. data preprocess

# %%
# generate labels
# for 10 objectives
image_size = 34
num_labels = 25
num_channels = 1

num_images = dataset.shape[0]
num_train = round(num_images*0.85)
num_valid = round(num_images*0.08)
num_test = round(num_images*0.1)

name2value = {'v8':0,'duck':1,'stapler':2,'pball':3,'tball':4,'sponge':5,'bclip':6,'tape':7,'gstick':8,'cup':9,
              'pen':10,'calc':11,'blade':12,'bottle':13,'cpin':14,'scissors':15,'stape':16,'gball':17,'orwidg':18,
             'glue':19,'spoon':20,'fork':21,'nerf':22,'eraser':23,'empty':24}
name2string = {'v8':'v8 can','duck':'ducky','stapler':'stapler','pball':'ping pang ball','tball':'tennis ball','sponge':'sponge',
               'bclip':'binder clip','tape':'big tape','gstick':'glue stick','cup':'cup','pen':'pen','calc':'calculator',
               'blade':'razor','bottle':'bottle','cpin':'clothespin','scissors':'scissors','stape':'small tape','gball':'golf ball',
               'orwidg':'orange thing','glue':'glue','spoon':'spoon','fork':'fork','nerf':'nerf gun','eraser':'eraser',
               'empty':'empty plate'}
value2name = dict((value,name) for name,value in name2value.items())    

labels = np.ndarray(num_images, dtype=np.int32)
index = 0
for name in names:
    labels[index] = name2value[name]
    index += 1
        
def randomize(dataset, labels):
    permutation = np.random.permutation(labels.shape[0])
    shuffled_dataset = dataset[permutation,:,:]
    shuffled_labels = labels[permutation]
    return shuffled_dataset, shuffled_labels

rdataset, rlabels = randomize(dataset, labels)
train_dataset = rdataset[0:num_train,:,:]
train_labels = rlabels[0:num_train]
valid_dataset = rdataset[num_train:(num_train+num_valid),:,:]
valid_labels = rlabels[num_train:(num_train+num_valid)]
test_dataset = rdataset[(num_train+num_valid):,:,:]
test_labels = rlabels[(num_train+num_valid):]
print('Training:', train_dataset.shape, train_labels.shape)
print('Validation:', valid_dataset.shape, valid_labels.shape)
print('Testing:', test_dataset.shape, test_labels.shape)
# Out:
# Training: (41310, 34, 34) (41310,)
# Validation: (3888, 34, 34) (3888,)
# Testing: (3402, 34, 34) (3402,)

# %% [markdown]
# display some images to verify that the data is still correct

# %%
indices = [random.randint(0,train_dataset.shape[0]) for x in range(30)]
for index in indices:
    image = train_dataset[index,:,:]
    print(value2name[train_labels[index]])
    plt.imshow(image,cmap='Greys_r')
    plt.show()
# Out:
# stapler
# stapler
# cup
# gball
# gstick
# eraser
# sponge
# empty
# sponge
# blade
# glue
# orwidg
# tape
# tape
# v8
# pen
# duck
# stapler
# eraser
# cpin
# stapler
# glue
# eraser
# scissors
# cpin
# stapler
# stapler
# cup
# blade
# bclip

# %%
print('......Reformatting......')

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels

train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# ......Reformatting......
# Training set (41310, 34, 34, 1) (41310, 25)
# Validation set (3888, 34, 34, 1) (3888, 25)
# Test set (3402, 34, 34, 1) (3402, 25)

# %% [markdown]
# #### 4. Define Costumed Function

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# #### 5. Build NN

# %%
batch_size = 30
patch_size = 5
kernel_size = 2
depth1 = 6 #the depth of 1st convnet
depth2 = 16 #the depth of 2nd convnet
C5_units = 120
F6_units = 84
F7_units = 10

graph = tf.Graph()

with graph.as_default():
    # Input data
    tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    # convolution's input is a tensor of shape [batch,in_height,in_width,in_channels]
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
    
    # Variables(weights and biases)
    C1_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, num_channels, depth1], stddev=0.1))
    # convolution's weights are called filter in tensorflow
    # it is a tensor of shape [kernel_hight,kernel_width,in_channels,out_channels]
    C1_biases = tf.Variable(tf.zeros([depth1]))
                            
    # S1_weights # Sub-sampling doesn't need weights and biases
    # S1_biases
    
    C3_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, depth1, depth2], stddev=0.1))
    C3_biases = tf.Variable(tf.constant(1.0, shape=[depth2]))
                            
    # S4_weights
    # S4_biases
     
    # C5 actually is a fully-connected layer                        
    C5_weights = tf.Variable(tf.truncated_normal([6 * 6 * depth2, C5_units], stddev=0.1))
    C5_biases = tf.Variable(tf.constant(1.0, shape=[C5_units]))
         
    F6_weights = tf.Variable(tf.truncated_normal([C5_units,F6_units], stddev=0.1))
    F6_biases = tf.Variable(tf.constant(1.0, shape=[F6_units]))
                                
    # FC and logistic regression replace RBF
    F7_weights = tf.Variable(tf.truncated_normal([F6_units,num_labels], stddev=0.1))
    F7_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))

    saver = tf.train.Saver()
    # Model
    def model(data):
        conv = tf.nn.conv2d(data, C1_weights, [1, 1, 1, 1], padding='SAME')
        hidden = tf.nn.relu(conv + C1_biases) # relu is better than tanh
        
        max_pool = tf.nn.max_pool(hidden,[1,kernel_size,kernel_size,1],[1,2,2,1],'VALID')
        hidden = tf.nn.relu(max_pool)
                                
        conv = tf.nn.conv2d(hidden, C3_weights, [1, 1, 1, 1], padding='VALID')
        hidden = tf.nn.relu(conv + C3_biases)

        max_pool = tf.nn.max_pool(hidden,[1,kernel_size,kernel_size,1],[1,2,2,1],'VALID')
        hidden = tf.nn.relu(max_pool)
                            
        shape = hidden.get_shape().as_list()
        reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, C5_weights) + C5_biases)
                            
        fc = tf.matmul(hidden,F6_weights)
        hidden = tf.nn.relu(fc + F6_biases)
        
        fc = tf.matmul(hidden,F7_weights)
        output = fc + F7_biases
    
        return output

    
    # Training computation.
    tf_train_dataset = tf.nn.dropout(tf_train_dataset,0.8) # input dropout
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.001).minimize(loss)
  
    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %% [markdown]
# #### 6. Train NN

# %%
## training
start_time = time.time()

num_steps = 200000
config = tf.ConfigProto()
config.log_device_placement = True
with tf.Session(graph=graph, config = config) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 2000 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(valid_prediction.eval(), valid_labels))
      print('--------------------------------------')
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
  end_time = time.time()
  duration = (end_time - start_time)/60
  print("Excution time: %0.2fmin" % duration)
  save_path = saver.save(session, "model.ckpt")
  print("Model saved in file: %s" % save_path)
  i_test = 0
  while(i_test!=''):
        i_test = input("Input an index of test image (or Enter to quit): ")
        label = test_labels[int(i_test),:].tolist()
        #print("Correct label: "+value2name[label.index(1)])
        image = test_dataset[int(i_test),:,:,:].reshape((-1,image_size,image_size,num_channels)).astype(np.float32)
        prediction = tf.nn.softmax(model(image))
        pre_dict = dict(zip(list(range(num_labels)),prediction.eval()[0]))
        sorted_pre_dict = sorted(pre_dict.items(), key=operator.itemgetter(1))
        name1 = value2name[sorted_pre_dict[-1][0]]
        name1 = name2string[name1]
        value1 = str(sorted_pre_dict[-1][1])
        name2 = value2name[sorted_pre_dict[-2][0]]
        name2 = name2string[name2]
        value2 = str(sorted_pre_dict[-2][1])
        tile = name1+': '+value1+'\n'+name2+': '+value2
        image = image.reshape((image_size,image_size)).astype(np.float32)
        plt.imshow(image,cmap='Greys_r')
        plt.suptitle(tile, fontsize=12)
        plt.xlabel(value2name[label.index(1)], fontsize=12)
        plt.show()
# Out:
# Initialized
# Minibatch loss at step 0: 6.118782
# Minibatch accuracy: 3.3%
# Validation accuracy: 3.9%
# --------------------------------------
# Minibatch loss at step 2000: 3.260119
# Minibatch accuracy: 10.0%
# Validation accuracy: 5.5%
# --------------------------------------
# Minibatch loss at step 4000: 3.160060
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.1%
# --------------------------------------
# Minibatch loss at step 6000: 2.546697
# Minibatch accuracy: 23.3%
# Validation accuracy: 14.8%
# --------------------------------------
# Minibatch loss at step 8000: 2.372790
# Minibatch accuracy: 10.0%
# Validation accuracy: 25.7%
# --------------------------------------
# Minibatch loss at step 10000: 1.742989
# Minibatch accuracy: 53.3%
# Validation accuracy: 34.2%
# --------------------------------------
# Minibatch loss at step 12000: 1.622578
# Minibatch accuracy: 46.7%
# Validation accuracy: 39.9%
# --------------------------------------
# Minibatch loss at step 14000: 1.964231
# Minibatch accuracy: 46.7%
# Validation accuracy: 41.9%
# --------------------------------------
# Minibatch loss at step 16000: 1.378398
# Minibatch accuracy: 60.0%
# Validation accuracy: 44.9%
# --------------------------------------
# Minibatch loss at step 18000: 1.255517
# Minibatch accuracy: 50.0%
# Validation accuracy: 49.3%
# --------------------------------------
# Minibatch loss at step 20000: 1.241838
# Minibatch accuracy: 50.0%
# Validation accuracy: 52.7%
# --------------------------------------
# Minibatch loss at step 22000: 1.539331
# Minibatch accuracy: 46.7%
# Validation accuracy: 55.4%
# --------------------------------------
# Minibatch loss at step 24000: 1.544260
# Minibatch accuracy: 53.3%
# Validation accuracy: 56.7%
# --------------------------------------
# Minibatch loss at step 26000: 1.176328
# Minibatch accuracy: 50.0%
# Validation accuracy: 55.7%
# --------------------------------------
# Minibatch loss at step 28000: 0.944731
# Minibatch accuracy: 70.0%
# Validation accuracy: 55.3%
# --------------------------------------
# Minibatch loss at step 30000: 1.143971
# Minibatch accuracy: 53.3%
# Validation accuracy: 61.6%
# --------------------------------------
# Minibatch loss at step 32000: 1.031853
# Minibatch accuracy: 66.7%
# Validation accuracy: 61.9%
# --------------------------------------
# Minibatch loss at step 34000: 0.876593
# Minibatch accuracy: 73.3%
# Validation accuracy: 65.5%
# --------------------------------------
# Minibatch loss at step 36000: 0.819228
# Minibatch accuracy: 70.0%
# Validation accuracy: 67.5%
# --------------------------------------
# Minibatch loss at step 38000: 0.827164
# Minibatch accuracy: 70.0%
# Validation accuracy: 69.3%
# --------------------------------------
# Minibatch loss at step 40000: 0.921051
# Minibatch accuracy: 73.3%
# Validation accuracy: 70.8%
# --------------------------------------
# Minibatch loss at step 42000: 1.294484
# Minibatch accuracy: 50.0%
# Validation accuracy: 65.5%
# --------------------------------------
# Minibatch loss at step 44000: 0.688218
# Minibatch accuracy: 73.3%
# Validation accuracy: 73.4%
# --------------------------------------
# Minibatch loss at step 46000: 0.595632
# Minibatch accuracy: 83.3%
# Validation accuracy: 76.7%
# --------------------------------------
# Minibatch loss at step 48000: 0.651092
# Minibatch accuracy: 80.0%
# Validation accuracy: 73.2%
# --------------------------------------
# Minibatch loss at step 50000: 0.489824
# Minibatch accuracy: 83.3%
# Validation accuracy: 78.5%
# --------------------------------------
# Minibatch loss at step 52000: 0.664415
# Minibatch accuracy: 66.7%
# Validation accuracy: 80.0%
# --------------------------------------
# Minibatch loss at step 54000: 0.311747
# Minibatch accuracy: 93.3%
# Validation accuracy: 79.8%
# --------------------------------------
# Minibatch loss at step 56000: 0.771916
# Minibatch accuracy: 66.7%
# Validation accuracy: 78.2%
# --------------------------------------
# Minibatch loss at step 58000: 0.405545
# Minibatch accuracy: 83.3%
# Validation accuracy: 77.0%
# --------------------------------------
# Minibatch loss at step 60000: 0.437784
# Minibatch accuracy: 83.3%
# Validation accuracy: 77.1%
# --------------------------------------
# Minibatch loss at step 62000: 0.535882
# Minibatch accuracy: 80.0%
# Validation accuracy: 82.1%
# --------------------------------------
# Minibatch loss at step 64000: 0.431353
# Minibatch accuracy: 83.3%
# Validation accuracy: 79.9%
# --------------------------------------
# Minibatch loss at step 66000: 0.242464
# Minibatch accuracy: 93.3%
# Validation accuracy: 84.2%
# --------------------------------------
# Minibatch loss at step 68000: 0.635689
# Minibatch accuracy: 76.7%
# Validation accuracy: 83.2%
# --------------------------------------
# Minibatch loss at step 70000: 0.308407
# Minibatch accuracy: 83.3%
# Validation accuracy: 87.3%
# --------------------------------------
# Minibatch loss at step 72000: 0.788158
# Minibatch accuracy: 66.7%
# Validation accuracy: 78.9%
# --------------------------------------
# Minibatch loss at step 74000: 0.475412
# Minibatch accuracy: 83.3%
# Validation accuracy: 83.0%
# --------------------------------------
# Minibatch loss at step 76000: 0.361990
# Minibatch accuracy: 86.7%
# Validation accuracy: 88.0%
# --------------------------------------
# Minibatch loss at step 78000: 0.545931
# Minibatch accuracy: 76.7%
# Validation accuracy: 85.8%
# --------------------------------------
# Minibatch loss at step 80000: 0.446386
# Minibatch accuracy: 80.0%
# Validation accuracy: 86.3%
# --------------------------------------
# Minibatch loss at step 82000: 0.485470
# Minibatch accuracy: 80.0%
# Validation accuracy: 88.3%
# --------------------------------------
# Minibatch loss at step 84000: 0.288318
# Minibatch accuracy: 96.7%
# Validation accuracy: 87.1%
# --------------------------------------
# Minibatch loss at step 86000: 0.610897
# Minibatch accuracy: 80.0%
# Validation accuracy: 83.3%
# --------------------------------------
# Minibatch loss at step 88000: 0.265308
# Minibatch accuracy: 96.7%
# Validation accuracy: 88.2%
# --------------------------------------
# Minibatch loss at step 90000: 0.504880
# Minibatch accuracy: 80.0%
# Validation accuracy: 87.5%
# --------------------------------------
# Minibatch loss at step 92000: 0.404549
# Minibatch accuracy: 86.7%
# Validation accuracy: 89.1%
# --------------------------------------
# Minibatch loss at step 94000: 0.354524
# Minibatch accuracy: 83.3%
# Validation accuracy: 88.8%
# --------------------------------------
# Minibatch loss at step 96000: 0.316053
# Minibatch accuracy: 90.0%
# Validation accuracy: 87.9%
# --------------------------------------
# Minibatch loss at step 98000: 0.484618
# Minibatch accuracy: 80.0%
# Validation accuracy: 87.3%
# --------------------------------------
# Minibatch loss at step 100000: 0.418415
# Minibatch accuracy: 76.7%
# Validation accuracy: 89.7%
# --------------------------------------
# Minibatch loss at step 102000: 0.230681
# Minibatch accuracy: 90.0%
# Validation accuracy: 88.4%
# --------------------------------------
# Minibatch loss at step 104000: 0.244859
# Minibatch accuracy: 96.7%
# Validation accuracy: 89.7%
# --------------------------------------
# Minibatch loss at step 106000: 0.185810
# Minibatch accuracy: 90.0%
# Validation accuracy: 90.1%
# --------------------------------------
# Minibatch loss at step 108000: 0.293332
# Minibatch accuracy: 90.0%
# Validation accuracy: 91.3%
# --------------------------------------
# Minibatch loss at step 110000: 0.084662
# Minibatch accuracy: 96.7%
# Validation accuracy: 90.6%
# --------------------------------------
# Minibatch loss at step 112000: 0.313136
# Minibatch accuracy: 90.0%
# Validation accuracy: 88.1%
# --------------------------------------
# Minibatch loss at step 114000: 0.328331
# Minibatch accuracy: 90.0%
# Validation accuracy: 90.7%
# --------------------------------------
# Minibatch loss at step 116000: 0.192956
# Minibatch accuracy: 96.7%
# Validation accuracy: 90.7%
# --------------------------------------
# Minibatch loss at step 118000: 0.185999
# Minibatch accuracy: 93.3%
# Validation accuracy: 91.0%
# --------------------------------------
# Minibatch loss at step 120000: 0.224998
# Minibatch accuracy: 90.0%
# Validation accuracy: 91.3%
# --------------------------------------
# Minibatch loss at step 122000: 0.229268
# Minibatch accuracy: 90.0%
# Validation accuracy: 91.9%
# --------------------------------------
# Minibatch loss at step 124000: 0.486781
# Minibatch accuracy: 80.0%
# Validation accuracy: 89.7%
# --------------------------------------
# Minibatch loss at step 126000: 0.129340
# Minibatch accuracy: 93.3%
# Validation accuracy: 90.8%
# --------------------------------------
# Minibatch loss at step 128000: 0.715765
# Minibatch accuracy: 80.0%
# Validation accuracy: 90.6%
# --------------------------------------
# Minibatch loss at step 130000: 0.128630
# Minibatch accuracy: 96.7%
# Validation accuracy: 90.6%
# --------------------------------------
# Minibatch loss at step 132000: 0.201640
# Minibatch accuracy: 93.3%
# Validation accuracy: 91.0%
# --------------------------------------
# Minibatch loss at step 134000: 0.115213
# Minibatch accuracy: 96.7%
# Validation accuracy: 92.1%
# --------------------------------------
# Minibatch loss at step 136000: 0.270956
# Minibatch accuracy: 86.7%
# Validation accuracy: 91.8%
# --------------------------------------
# Minibatch loss at step 138000: 0.198428
# Minibatch accuracy: 90.0%
# Validation accuracy: 93.0%
# --------------------------------------
# Minibatch loss at step 140000: 0.116706
# Minibatch accuracy: 96.7%
# Validation accuracy: 92.6%
# --------------------------------------
# Minibatch loss at step 142000: 0.163663
# Minibatch accuracy: 90.0%
# Validation accuracy: 93.0%
# --------------------------------------
# Minibatch loss at step 144000: 0.216108
# Minibatch accuracy: 93.3%
# Validation accuracy: 93.0%
# --------------------------------------
# Minibatch loss at step 146000: 0.143617
# Minibatch accuracy: 100.0%
# Validation accuracy: 93.0%
# --------------------------------------
# Minibatch loss at step 148000: 0.066433
# Minibatch accuracy: 100.0%
# Validation accuracy: 93.0%
# --------------------------------------
# Minibatch loss at step 150000: 0.300962
# Minibatch accuracy: 86.7%
# Validation accuracy: 92.7%
# --------------------------------------
# Minibatch loss at step 152000: 0.185656
# Minibatch accuracy: 93.3%
# Validation accuracy: 93.4%
# --------------------------------------
# Minibatch loss at step 154000: 0.086340
# Minibatch accuracy: 100.0%
# Validation accuracy: 93.2%
# --------------------------------------
# Minibatch loss at step 156000: 0.073539
# Minibatch accuracy: 96.7%
# Validation accuracy: 93.9%
# --------------------------------------
# Minibatch loss at step 158000: 0.133270
# Minibatch accuracy: 93.3%
# Validation accuracy: 93.4%
# --------------------------------------
# Minibatch loss at step 160000: 0.261340
# Minibatch accuracy: 90.0%
# Validation accuracy: 93.5%
# --------------------------------------
# Minibatch loss at step 162000: 0.163473
# Minibatch accuracy: 96.7%
# Validation accuracy: 93.9%
# --------------------------------------
# Minibatch loss at step 164000: 0.066281
# Minibatch accuracy: 100.0%
# Validation accuracy: 93.8%
# --------------------------------------
# Minibatch loss at step 166000: 0.077215
# Minibatch accuracy: 100.0%
# Validation accuracy: 94.3%
# --------------------------------------
# Minibatch loss at step 168000: 0.078020
# Minibatch accuracy: 100.0%
# Validation accuracy: 91.9%
# --------------------------------------
# Minibatch loss at step 170000: 0.062103
# Minibatch accuracy: 100.0%
# Validation accuracy: 93.7%
# --------------------------------------
# Minibatch loss at step 172000: 0.220498
# Minibatch accuracy: 93.3%
# Validation accuracy: 94.0%
# --------------------------------------
# Minibatch loss at step 174000: 0.032492
# Minibatch accuracy: 100.0%
# Validation accuracy: 95.0%
# --------------------------------------
# Minibatch loss at step 176000: 0.057382
# Minibatch accuracy: 100.0%
# Validation accuracy: 93.8%
# --------------------------------------
# Minibatch loss at step 178000: 0.096135
# Minibatch accuracy: 96.7%
# Validation accuracy: 94.2%
# --------------------------------------
# Minibatch loss at step 180000: 0.087050
# Minibatch accuracy: 100.0%
# Validation accuracy: 94.6%
# --------------------------------------
# Minibatch loss at step 182000: 0.153572
# Minibatch accuracy: 96.7%
# Validation accuracy: 94.1%
# --------------------------------------
# Minibatch loss at step 184000: 0.303172
# Minibatch accuracy: 93.3%
# Validation accuracy: 92.5%
# --------------------------------------
# Minibatch loss at step 186000: 0.152773
# Minibatch accuracy: 93.3%
# Validation accuracy: 93.8%
# --------------------------------------
# Minibatch loss at step 188000: 0.056767
# Minibatch accuracy: 100.0%
# Validation accuracy: 94.0%
# --------------------------------------
# Minibatch loss at step 190000: 0.027201
# Minibatch accuracy: 100.0%
# Validation accuracy: 94.3%
# --------------------------------------
# Minibatch loss at step 192000: 0.243801
# Minibatch accuracy: 90.0%
# Validation accuracy: 95.0%
# --------------------------------------
# Minibatch loss at step 194000: 0.136719
# Minibatch accuracy: 93.3%
# Validation accuracy: 96.2%
# --------------------------------------
# Minibatch loss at step 196000: 0.248404
# Minibatch accuracy: 90.0%
# Validation accuracy: 93.9%
# --------------------------------------
# Minibatch loss at step 198000: 0.175065
# Minibatch accuracy: 93.3%
# Validation accuracy: 93.8%
# --------------------------------------
# Test accuracy: 95.7%
# Excution time: 37.26min
# Model saved in file: model.ckpt
# Input an index of test image (or Enter to quit):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-7a9f17275895> in <module>()
#      29   while(i_test!=''):
#      30         i_test = input("Input an index of test image (or Enter to quit): ")
# ---> 31         label = test_labels[int(i_test),:].tolist()
#      32         #print("Correct label: "+value2name[label.index(1)])
#      33         image = test_dataset[int(i_test),:,:,:].reshape((-1,image_size,image_size,num_channels)).astype(np.float32)
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# ## Use the Trained Variables

# %%
batch_size = 16
patch_size = 5
kernel_size = 2
depth1 = 6 #the depth of 1st convnet
depth2 = 16 #the depth of 2nd convnet
C5_units = 120
F6_units = 84
F7_units = 10

graph = tf.Graph()

with graph.as_default():
    # Input data
    tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    # convolution's input is a tensor of shape [batch,in_height,in_width,in_channels]
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
    
    # Variables(weights and biases)
    C1_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, num_channels, depth1], stddev=0.1))
    # convolution's weights are called filter in tensorflow
    # it is a tensor of shape [kernel_hight,kernel_width,in_channels,out_channels]
    C1_biases = tf.Variable(tf.zeros([depth1]))
                            
    # S1_weights # Sub-sampling doesn't need weights and biases
    # S1_biases
    
    C3_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, depth1, depth2], stddev=0.1))
    C3_biases = tf.Variable(tf.constant(1.0, shape=[depth2]))
                            
    # S4_weights
    # S4_biases
     
    # C5 actually is a fully-connected layer                        
    C5_weights = tf.Variable(tf.truncated_normal([6 * 6 * depth2, C5_units], stddev=0.1))
    C5_biases = tf.Variable(tf.constant(1.0, shape=[C5_units]))
         
    F6_weights = tf.Variable(tf.truncated_normal([C5_units,F6_units], stddev=0.1))
    F6_biases = tf.Variable(tf.constant(1.0, shape=[F6_units]))
                                
    # FC and logistic regression replace RBF
    F7_weights = tf.Variable(tf.truncated_normal([F6_units,num_labels], stddev=0.1))
    F7_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))

    saver = tf.train.Saver()
    # Model
    def model(data):
        conv = tf.nn.conv2d(data, C1_weights, [1, 1, 1, 1], padding='SAME')
        hidden = tf.nn.relu(conv + C1_biases) # relu is better than tanh
        
        max_pool = tf.nn.max_pool(hidden,[1,kernel_size,kernel_size,1],[1,2,2,1],'VALID')
        hidden = tf.nn.relu(max_pool)
                                
        conv = tf.nn.conv2d(hidden, C3_weights, [1, 1, 1, 1], padding='VALID')
        hidden = tf.nn.relu(conv + C3_biases)

        max_pool = tf.nn.max_pool(hidden,[1,kernel_size,kernel_size,1],[1,2,2,1],'VALID')
        hidden = tf.nn.relu(max_pool)
                            
        shape = hidden.get_shape().as_list()
        reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, C5_weights) + C5_biases)
                            
        fc = tf.matmul(hidden,F6_weights)
        hidden = tf.nn.relu(fc + F6_biases)
        
        fc = tf.matmul(hidden,F7_weights)
        output = fc + F7_biases
    
        return output

    
    # Training computation.
    tf_train_dataset = tf.nn.dropout(tf_train_dataset,0.8) # input dropout
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.0008).minimize(loss)
  
    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))
    
config = tf.ConfigProto()
config.log_device_placement = True   
#wd = os.getcwd()
with tf.Session(graph=graph, config = config) as session:
  saver.restore(session, "model.ckpt")
  print("Model restored.")
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
  i_test = 0
  while(i_test!=''):
        i_test = input("Input an index of test image (or Enter to quit): ")
        label = test_labels[int(i_test),:].tolist()
        #print("Correct label: "+value2name[label.index(1)])
        image = test_dataset[int(i_test),:,:,:].reshape((-1,image_size,image_size,num_channels)).astype(np.float32)
        prediction = tf.nn.softmax(model(image))
        pre_dict = dict(zip(list(range(num_labels)),prediction.eval()[0]))
        sorted_pre_dict = sorted(pre_dict.items(), key=operator.itemgetter(1))
        name1 = value2name[sorted_pre_dict[-1][0]]
        value1 = str(sorted_pre_dict[-1][1])
        name2 = value2name[sorted_pre_dict[-2][0]]
        value2 = str(sorted_pre_dict[-2][1])
        tile = name1+': '+value1+'\n'+name2+': '+value2
        image = image.reshape((image_size,image_size)).astype(np.float32)
        plt.imshow(image,cmap='Greys_r')
        plt.suptitle(tile, fontsize=12)
        plt.xlabel(value2name[label.index(1)], fontsize=12)
        plt.show()
# Out:
# Model restored.
# -----------------------------------------------------------------------
# NameError                             Traceback (most recent call last)
# <ipython-input-7-e31310745ad2> in <module>()
#      91   saver.restore(session, "model.ckpt")
#      92   print("Model restored.")
# ---> 93   print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
#      94   i_test = 0
#      95   while(i_test!=''):
#
# NameError: name 'test_prediction' is not defined
